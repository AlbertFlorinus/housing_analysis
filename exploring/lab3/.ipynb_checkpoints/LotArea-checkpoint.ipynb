# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import ipywidgets as widgets
from ipywidgets import interact
import scipy.stats as stats

# %%
df = pd.read_csv('train.csv', sep=',')
#df = df[df.LotArea < 30000]
lot = df.LotArea
lot = df.GrLivArea
price = df.SalePrice

# %%
fig = plt.figure(figsize=(9,5))
ax = fig.add_subplot()

ax.scatter(lot, price, label="LotArea vs SalePrice", color="red", s=2)
ax.set_title("LotArea vs SalePrice")
ax.set_xlabel("LotArea")
ax.set_ylabel("SalePrice")
ax.grid()
ax.legend()

# %%
deg = 2
data_reg = np.polyfit(lot, price, deg)
xp = np.linspace(0.0, max(lot), 20)
yp = np.polyval(data_reg, lot)

fig = plt.figure(figsize=(14,8))
ax = fig.add_subplot()
ax.scatter(lot, price, label="LotArea vs SalePrice", color="gray", s =1)
#ax.plot(xp, yp, label="Pol. Reg.")
ax.plot(xp, np.polyval(data_reg, xp))
ax.set_title("LotArea vs SalePrice")
ax.grid()
ax.set_xlabel("LotArea")
ax.set_ylabel("SalePrice")
predicted_values = yp
true_values = price
#print(predicted_values)
#print(true_values)
correlation , pval = stats.spearmanr(yp, price)
correlation
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1044/2400013229.py in <module>
#       7 ax = fig.add_subplot()
#       8 ax.scatter(lot, price, label="LotArea vs SalePrice", color="gray", s =1)
# ----> 9 ax.plot(xp, yp, label="Pol. Reg.")
#      10 ax.set_title("LotArea vs SalePrice")
#      11 ax.grid()
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     496
#     497         if x.shape[0] != y.shape[0]:
# --> 498             raise ValueError(f"x and y must have same first dimension, but "
#     499                              f"have shapes {x.shape} and {y.shape}")
#     500         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (20,) and (1460,)

# %%
predicted_values = yp
true_values = price
print(predicted_values)
#print(lot)
print(true_values)
print(stats.kendalltau(predicted_values, true_values))
# Out:
# [-13283.68850584 -12720.9976129  -12158.61328827 ... 481381.16760978
#  481497.18848226 481612.90278644]
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64
# KendalltauResult(correlation=-0.012030176443021415, pvalue=0.4915591949626421)

# %%
correlation , pval = stats.kendalltau(yp, price)
correlation
# Out:
# -0.0039831099155334644
